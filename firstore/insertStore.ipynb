# %%
#lib import
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
from firebase_admin import auth
import requests

# %%
#auth
cred = credentials.Certificate('mykey.json')
firebase_admin.initialize_app(cred,{
    'databaseURL' : 'https://together-at001.firebaseio.com/'
    
})
db = firestore.client()

# %%
#insert storeList_test
doc_ref = db.collection(u'storeList').document(u'A칵테일')
doc_ref.set({
    u'add' : '대구 달서구 선원로 60',
    u'add1' : '대구',
    u'add2' : '달서구',
    u'add3' : '신당동',
    u'category' : '주점',
    u'email' : 'bar06@together.com',
    u'phone1' : '010',
    u'phone2' : '40000006',
    u'relief' : 0,
    u'storeName' : 'A칵테일',
    u'storeNum' : '4000000006',
    u'uid' : '8WCITEE8kUThwELEcz9I2DmqJdZ2',
    u'x' : '128.498821737472',
    u'y' : '35.8589615482504',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})
# Out:
# update_time {
#   seconds: 1599327103
#   nanos: 659681000
# }

# %%
#insert cafe
doc_ref1 = db.collection(u'storeList').document(u'옥룡bar')
doc_ref1.set({
    u'add' : '충남 공주시 무령로342',
    u'add1' : '충남',
    u'add2' : '공주시',
    u'add3' : '옥룡동',
    u'category' : '주점',
    u'email' : 'bar07@together.com',
    u'phone1' : '010',
    u'phone2' : '40000007',
    u'relief' : 0,
    u'storeName' : '옥룡bar',
    u'storeNum' : '4000000007',
    u'uid' : 'yCc1YECVEuTiXzumIxpDqITperH3',
    u'x' : '127.13727343177',
    u'y' : '36.4574937199381',
    u'url' : ''
    
})
doc_ref2 = db.collection(u'storeList').document(u'A카페 합정점')
doc_ref2.set({
    u'add' : '서울 마포구 동교로15길 7',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '서교동',
    u'category' : '카페',
    u'email' : 'cafe01@together.com',
    u'phone1' : '010',
    u'phone2' : '00000001',
    u'relief' : 3500,
    u'storeName' : 'A카페 합정점',
    u'storeNum' : '0000000001',
    u'uid' : 'm4OUbQr1enUK3f0lm1UI7fEKY223',
    u'x' : '126.91459072348',
    u'y' : '37.5551093133912',
    
})
doc_ref0 = db.collection(u'storeList').document(u'Cafe&Bakery')
doc_ref0.set({
    u'add' : '서울 마포구 월드컵로 212',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '성산동',
    u'category' : '카페',
    u'email' : 'cafe02@together.com',
    u'phone1' : '010',
    u'phone2' : '00000002',
    u'relief' : 35,
    u'storeName' : 'Cafe&Bakery',
    u'storeNum' : '0000000002',
    u'uid' : '0VlEQ00lKHWVI54DG4lptrOmPju2',
    u'x' : '126.903425598797',
    u'y' : '37.5634871865932',
    
})

doc_ref3 = db.collection(u'storeList').document(u'Coffe')
doc_ref3.set({
    u'add' : '서울 서대문구 연희로 248',
    u'add1' : '서울',
    u'add2' : '서대문구',
    u'add3' : '연희동',
    u'category' : '카페',
    u'email' : 'cafe03@together.com',
    u'phone1' : '010',
    u'phone2' : '00000003',
    u'relief' : 0,
    u'storeName' : 'Coffe',
    u'storeNum' : '0000000003',
    u'uid' : 'Vbvd5eLZ58ZKk68QFBtsaOCLG5C2',
    u'x' : '126.9368156604',
    u'y' : '37.5791618639849',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

doc_ref4 = db.collection(u'storeList').document(u'1리터 대용량 커피')
doc_ref4.set({
    u'add' : '서울 용산구 녹사평대로 150',
    u'add1' : '서울',
    u'add2' : '용산구',
    u'add3' : '이태원동',
    u'category' : '카페',
    u'email' : 'cafe04@together.com',
    u'phone1' : '010',
    u'phone2' : '00000004',
    u'relief' : 0,
    u'storeName' : 'Coffe',
    u'storeNum' : '0000000004',
    u'uid' : 'XlDJCGlZjxgj6X1nKo3xDz0blbH2',
    u'x' : '126.990582345331',
    u'y' : '37.532431039138',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

doc_ref5 = db.collection(u'storeList').document(u'CafeCafe')
doc_ref5.set({
    u'add' : '경기 고양시 덕양구 화중로104번길 13',
    u'add1' : '경기',
    u'add2' : '고양시 덕양구',
    u'add3' : '화정동',
    u'category' : '카페',
    u'email' : 'cafe05@together.com',
    u'phone1' : '010',
    u'phone2' : '00000005',
    u'relief' : 0,
    u'storeName' : 'CafeCafe',
    u'storeNum' : '0000000005',
    u'uid' : 'JVRRMrWfFDc40fPEB1Cjy7K3nfA3',
    u'x' : '126.832188086805',
    u'y' : '37.6374795939374',
    
    
})

doc_ref6 = db.collection(u'storeList').document(u'C coffee')
doc_ref6.set({
    u'add' : '경기 안양시 동안구 동안로 158',
    u'add1' : '경기',
    u'add2' : '안양시 동안구',
    u'add3' : '비산동',
    u'category' : '카페',
    u'email' : 'cafe06@together.com',
    u'phone1' : '010',
    u'phone2' : '00000006',
    u'relief' : 0,
    u'storeName' : 'C coffee',
    u'storeNum' : '0000000006',
    u'uid' : 'Eq6qns7RMZhUKYM5rOYkqgskhO62',
    u'x' : '126.951422855867',
    u'y' : '37.3926060215039',
    
    
})

doc_ref7 = db.collection(u'storeList').document(u'abcd카페')
doc_ref7.set({
    u'add' : '전북 익산시 인북로 353',
    u'add1' : '전북',
    u'add2' : '익산시',
    u'add3' : '신동',
    u'category' : '카페',
    u'email' : 'cafe07@together.com',
    u'phone1' : '010',
    u'phone2' : '00000007',
    u'relief' : 0,
    u'storeName' : 'abcd카페',
    u'storeNum' : '0000000007',
    u'uid' : 'cf2wMBuVBvP73Mjz5xR7Tdqz2aN2',
    u'x' : '126.961321101795',
    u'y' : '35.9598287857317',
    
    
})
# Out:
# update_time {
#   seconds: 1599321837
#   nanos: 151979000
# }

# %%
#insert food
food_ref1 = db.collection(u'storeList').document(u'A한식당')
food_ref1.set({
    u'add' : '경기 고양시 덕양구 원흥1로 23',
    u'add1' : '경기',
    u'add2' : '고양시 덕양구',
    u'add3' : '원흥동',
    u'category' : '음식점',
    u'email' : 'food01@together.com',
    u'phone1' : '010',
    u'phone2' : '10000001',
    u'relief' : 0,
    u'storeName' : 'A한식당',
    u'storeNum' : '1000000001',
    u'uid' : '3crJ4o2PTccAWn3w9GBop2u26mD3',
    u'x' : '126.86680837143598',
    u'y' : '37.65083578631229',
    u'url' : ''
    
    
})
food_ref2 = db.collection(u'storeList').document(u'A중식당 서교 본점')
food_ref2.set({
    u'add' : '서울 마포구 월드컵북로30길 22',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '성산동',
    u'category' : '음식점',
    u'email' : 'food02@together.com',
    u'phone1' : '010',
    u'phone2' : '10000002',
    u'relief' : 0,
    u'storeName' : 'A중식당 서교 본점',
    u'storeNum' : '1000000002',
    u'uid' : 'tNj4kpeICrRD2mlkVCJkSskZrHf1',
    u'x' : '126.9089970914',
    u'y' : '37.56865612002',
    u'url' : ''
    
    
})
food_ref3 = db.collection(u'storeList').document(u'C파스타')
food_ref3.set({
    u'add' : '서울 마포구 성산로4길 15',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '성산동',
    u'category' : '음식점',
    u'email' : 'food03@together.com',
    u'phone1' : '010',
    u'phone2' : '10000003',
    u'relief' : 0,
    u'storeName' : 'C파스타',
    u'storeNum' : '1000000003',
    u'uid' : 'E30vQ0kjLldw1KrpxgUWbUZfBE42',
    u'x' : '126.907889758422',
    u'y' : '37.5633862382623',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

food_ref4 = db.collection(u'storeList').document(u'B분식')
food_ref4.set({
    u'add' : '경남 창원시 성산구 대암로 109',
    u'add1' : '경남',
    u'add2' : '창원시 성산구',
    u'add3' : '대방동',
    u'category' : '음식점',
    u'email' : 'food04@together.com',
    u'phone1' : '010',
    u'phone2' : '10000004',
    u'relief' : 0,
    u'storeName' : 'B분식',
    u'storeNum' : '1000000004',
    u'uid' : 'H79yMb061VXBk7Ih9tDaMoPZFSv2',
    u'x' : '128.70870588885938',
    u'y' : '35.21590165802239',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

food_ref5 = db.collection(u'storeList').document(u'E치킨')
food_ref5.set({
    u'add' : '서울 마포구 성산로128 101호',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '성산동',
    u'category' : '음식점',
    u'email' : 'food05@together.com',
    u'phone1' : '010',
    u'phone2' : '10000005',
    u'relief' : 0,
    u'storeName' : 'E치킨',
    u'storeNum' : '1000000005',
    u'uid' : 'OkefSzKdpIcWsjh2p0E8en6EKR62',
    u'x' : '126.90823203106093',
    u'y' : '37.56393971639653',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

food_ref6 = db.collection(u'storeList').document(u'D도시락 합정점')
food_ref6.set({
    u'add' : '서울 마포구 월드컵북로30길 22 209호',
    u'add1' : '서울',
    u'add2' : '마포구',
    u'add3' : '성산동',
    u'category' : '음식점',
    u'email' : 'food06@together.com',
    u'phone1' : '010',
    u'phone2' : '10000006',
    u'relief' : 0,
    u'storeName' : 'D도시락 합정점',
    u'storeNum' : '1000000006',
    u'uid' : '2eoQx6RezidDZ7QZ3TiONq66tTc2',
    u'x' : '126.908929197471',
    u'y' : '37.568638047766',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

food_ref7 = db.collection(u'storeList').document(u'비빔밥24')
food_ref7.set({
    u'add' : '전북 전주시 완산구 서신천변14길 10',
    u'add1' : '전북',
    u'add2' : '전주시 완산구',
    u'add3' : '서신동',
    u'category' : '음식점',
    u'email' : 'food07@together.com',
    u'phone1' : '010',
    u'phone2' : '10000007',
    u'relief' : 0,
    u'storeName' : '비빔밥 24',
    u'storeNum' : '1000000007',
    u'uid' : 'KiSuEZ3TWSYqU9pWc1euEo5KXHF3',
    u'x' : '127.115308857863',
    u'y' : '35.8310848804895',
    u'url' : ''
   
    
})
# Out:
# update_time {
#   seconds: 1599323814
#   nanos: 491564000
# }

# %%
#insert karaoke
ka_ref1 = db.collection(u'storeList').document(u'D노래방 신촌점')
ka_ref1.set({
    u'add' : '서울 서대문구 모래내로 334',
    u'add1' : '서울',
    u'add2' : '서대문구',
    u'add3' : '홍은동',
    u'category' : '노래방',
    u'email' : 'karaoke01@together.com',
    u'phone1' : '010',
    u'phone2' : '20000001',
    u'relief' : 0,
    u'storeName' : 'D노래방 신촌점',
    u'storeNum' : '2000000001',
    u'uid' : 'dKFv3xE79LO84kYlsr5yCDbd01q1',
    u'x' : '126.934229091144',
    u'y' : '37.5801515443579',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

ka_ref2 = db.collection(u'storeList').document(u'마이크')
ka_ref2.set({
    u'add' : '서울 강서구 양천로67가길 63',
    u'add1' : '서울',
    u'add2' : '강서구',
    u'add3' : '염창동',
    u'category' : '노래방',
    u'email' : 'karaoke02@together.com',
    u'phone1' : '010',
    u'phone2' : '20000002',
    u'relief' : 0,
    u'storeName' : '마이크',
    u'storeNum' : '2000000002',
    u'uid' : 'lqYtc4fosjZ6BjrlEBx6wppkAI52',
    u'x' : '126.870985348961',
    u'y' : '37.5537362431415',
    u'url' : ''
    
})

ka_ref3 = db.collection(u'storeList').document(u'STAR 노래방')
ka_ref3.set({
    u'add' : '서울 강서구 곰달래로 79',
    u'add1' : '서울',
    u'add2' : '강서구',
    u'add3' : '화곡동',
    u'category' : '노래방',
    u'email' : 'karaoke03@together.com',
    u'phone1' : '010',
    u'phone2' : '20000003',
    u'relief' : 0,
    u'storeName' : 'STAR 노래방',
    u'storeNum' : '2000000003',
    u'uid' : 'O68U5VVo73UApoG0gsnbLY4aId73',
    u'x' : '126.84159905180285',
    u'y' : '37.530391638187226',
    u'url' : ''
    
})

ka_ref4 = db.collection(u'storeList').document(u'Sing')
ka_ref4.set({
    u'add' : '경북 포항시 북구 장량로 50',
    u'add1' : '경북',
    u'add2' : '포항시 북구',
    u'add3' : '장성동',
    u'category' : '노래방',
    u'email' : 'karaoke04@together.com',
    u'phone1' : '010',
    u'phone2' : '20000004',
    u'relief' : 0,
    u'storeName' : 'Sing',
    u'storeNum' : '2000000004',
    u'uid' : '6GOv5kABgxMO9doEhC4YcKD3yVG3',
    u'x' : '129.38589383107097',
    u'y' : '36.081983652653896',
    u'url' : ''
    
})

ka_ref5 = db.collection(u'storeList').document(u'A노래방')
ka_ref5.set({
    u'add' : '경북 포항시 북구 삼호로 260',
    u'add1' : '경북',
    u'add2' : '포항시 북구',
    u'add3' : '두호동',
    u'category' : '노래방',
    u'email' : 'karaoke05@together.com',
    u'phone1' : '010',
    u'phone2' : '20000005',
    u'relief' : 0,
    u'storeName' : 'A노래방',
    u'storeNum' : '2000000005',
    u'uid' : 'ENwxCn1xY8OwfwTpH4IN9NTWA2y2',
    u'x' : '129.380085340895',
    u'y' : '36.0609207138005',
    u'url' : ''
    
})

ka_ref6 = db.collection(u'storeList').document(u'B노래방')
ka_ref6.set({
    u'add' : '경북 포항시 남구 연일읍 철강로 10',
    u'add1' : '경북',
    u'add2' : '포항시 남구',
    u'add3' : '연일읍',
    u'category' : '노래방',
    u'email' : 'karaoke06@together.com',
    u'phone1' : '010',
    u'phone2' : '20000006',
    u'relief' : 0,
    u'storeName' : 'B노래방',
    u'storeNum' : '2000000006',
    u'uid' : 'dg7MlbshkZXsqX0Q2kSTm0fZMTr2',
    u'x' : '129.34415035615322',
    u'y' : '35.99162005072084',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

ka_ref7 = db.collection(u'storeList').document(u'노래 노래방')
ka_ref7.set({
    u'add' : '강원 강릉시 하슬라로 173',
    u'add1' : '강원',
    u'add2' : '강릉시',
    u'add3' : '교동',
    u'category' : '노래방',
    u'email' : 'karaoke07@together.com',
    u'phone1' : '010',
    u'phone2' : '20000007',
    u'relief' : 0,
    u'storeName' : 'B노래방',
    u'storeNum' : '2000000007',
    u'uid' : 'p9YAetHKxSdfH4dcVh9IwZCc6sR2',
    u'x' : '128.874395269186',
    u'y' : '37.7656087642187',
    u'url' : ''
    
})
# Out:
# update_time {
#   seconds: 1599324027
#   nanos: 930672000
# }

# %%
#insert PCRoom
pc_ref1 = db.collection(u'storeList').document(u'C피시방 신촌점')
pc_ref1.set({
    u'add' : '서울 서대문구 신촌로 지하 90',
    u'add1' : '서울',
    u'add2' : '서대문구',
    u'add3' : '창천동',
    u'category' : '피시방',
    u'email' : 'pc01@together.com',
    u'phone1' : '010',
    u'phone2' : '30000001',
    u'relief' : 0,
    u'storeName' : 'C피시방 신촌점',
    u'storeNum' : '3000000001',
    u'uid' : 'wcoFPcBpoYRtRfumt3Sgg4o5Nd42',
    u'x' : '126.93698075917935',
    u'y' : '37.55519907036358',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

pc_ref2 = db.collection(u'storeList').document(u'APC')
pc_ref2.set({
    u'add' : '서울 동대문구 사가정로 230-1',
    u'add1' : '서울',
    u'add2' : '동대문구',
    u'add3' : '장안동',
    u'category' : '피시방',
    u'email' : 'pc02@together.com',
    u'phone1' : '010',
    u'phone2' : '30000002',
    u'relief' : 0,
    u'storeName' : 'APC',
    u'storeNum' : '3000000002',
    u'uid' : 'Zr8BY3J9mxfbrfcMPyp3RXzYoHk2',
    u'x' : '127.070614728747',
    u'y' : '37.5784584817718',
    u'url' : ''
    
})

pc_ref3 = db.collection(u'storeList').document(u'피시존')
pc_ref3.set({
    u'add' : '경기 수원시 영통구 매영로39번길 21',
    u'add1' : '경기',
    u'add2' : '수원시 영통구',
    u'add3' : '매탄동',
    u'category' : '피시방',
    u'email' : 'pc03@together.com',
    u'phone1' : '010',
    u'phone2' : '30000003',
    u'relief' : 0,
    u'storeName' : '피시존',
    u'storeNum' : '3000000003',
    u'uid' : 'Hs74w3bGwPREQ6xdLRaQciOeZOI3',
    u'x' : '127.047434034325',
    u'y' : '37.2701238257665',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

pc_ref4 = db.collection(u'storeList').document(u'PCIE')
pc_ref4.set({
    u'add' : '부산 해운대구 좌동순환로 302',
    u'add1' : '부산',
    u'add2' : '해운대구',
    u'add3' : '좌동동',
    u'category' : '피시방',
    u'email' : 'pc04@together.com',
    u'phone1' : '010',
    u'phone2' : '30000004',
    u'relief' : 0,
    u'storeName' : 'PCIE',
    u'storeNum' : '3000000004',
    u'uid' : 'VB2VDKWlxZN834bZCzS6LBVnvoO2',
    u'x' : '129.182597904042',
    u'y' : '35.1691489674503',
    u'url' : ''
    
})

pc_ref5 = db.collection(u'storeList').document(u'스마트 피시방')
pc_ref5.set({
    u'add' : '인천 서구 청라라임로 58',
    u'add1' : '인천',
    u'add2' : '서구',
    u'add3' : '청라동',
    u'category' : '피시방',
    u'email' : 'pc05@together.com',
    u'phone1' : '010',
    u'phone2' : '30000005',
    u'relief' : 0,
    u'storeName' : '스마트 피시방',
    u'storeNum' : '3000000005',
    u'uid' : '0JM4kztQAqR6n6GnTJ5sgWcF5lv2',
    u'x' : '126.65369152973',
    u'y' : '37.532626433709',
    u'url' : 'https://www.instagram.com/atcompany2020/'
    
})

pc_ref6 = db.collection(u'storeList').document(u'스타피시방')
pc_ref6.set({
    u'add' : '대구 달서구 진천로9길 33',
    u'add1' : '대구',
    u'add2' : '달서구',
    u'add3' : '진천동',
    u'category' : '피시방',
    u'email' : 'pc06@together.com',
    u'phone1' : '010',
    u'phone2' : '30000006',
    u'relief' : 0,
    u'storeName' : '스타피시방',
    u'storeNum' : '3000000006',
    u'uid' : 'rdhKMMv7HVSs24JxJkg6StQw0qt1',
    u'x' : '128.52280850304',
    u'y' : '35.8121889693963',
    u'url' : ''
    
})

pc_ref7 = db.collection(u'storeList').document(u'pc1')
pc_ref7.set({
    u'add' : '대구 달서구 진천로9길 33',
    u'add1' : '대구',
    u'add2' : '달서구',
    u'add3' : '진천동',
    u'category' : '피시방',
    u'email' : 'pc07@together.com',
    u'phone1' : '010',
    u'phone2' : '30000007',
    u'relief' : 0,
    u'storeName' : '스타피시방',
    u'storeNum' : '3000000007',
    u'uid' : 'xzhbC8tfz2QKnpuQVehEOdBoAdW2',
    u'x' : '127.42642113887',
    u'y' : '36.36062424262',
    u'url' : ''
    
})
# Out:
# update_time {
#   seconds: 1599324973
#   nanos: 877759000
# }
