# %%
#import sdk
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
from firebase_admin import auth
import requests
from datetime import datetime # to insert date

# %%
#auth
cred = credentials.Certificate('mykey.json')
firebase_admin.initialize_app(cred,{
    'databaseURL' : 'https://together-at001.firebaseio.com/'
    
})
db = firestore.client()

# %%
#insert cafe checklist(26lists)

#case1 : 모두 true인 경우
doc_ref = db.collection(u'checkListCafe').document(u'A카페 합정점')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : True,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case2 : 공통항목 한개가 f인 경우
doc_ref = db.collection(u'checkListCafe').document(u'Cafe&Bakery')
doc_ref.set({
    u'1' : False,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : True,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case3 : 개별항목 공통항목 하나씩f인 경우
doc_ref = db.collection(u'checkListCafe').document(u'Coffe')
doc_ref.set({
    u'1' : True,
    u'2' : False,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : True,
    u'7' : False,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case4 : 개별항목 한개가 f인 경우
doc_ref = db.collection(u'checkListCafe').document(u'1리터 대용량 커피')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : False,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case5 : 공통항목 두개가 f인 경우
doc_ref = db.collection(u'checkListCafe').document(u'CafeCafe')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : False,
    u'4' : False,
    u'5' : True,
    u'6' : True,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case6 : 개별항목 두개 f
doc_ref = db.collection(u'checkListCafe').document(u'abcd카페')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : True,
    u'7' : False,
    u'8' : False,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})

#case7 : 공통항목, 개별항목 섞어서 F
doc_ref = db.collection(u'checkListCafe').document(u'C coffee')
doc_ref.set({
    u'1' : False,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : False,
    u'6' : False,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})
# Out:
# update_time {
#   seconds: 1599326219
#   nanos: 678588000
# }

# %%
#insert restaurant checklist(26lists)

#case7 : 아이콘 번갈아 가면서
doc_ref = db.collection(u'checkListFood').document(u'A한식당')
doc_ref.set({
    u'1' : False,
    u'2' : True,
    u'3' : False,
    u'4' : True,
    u'5' : False,
    u'6' : True,
    u'7' : False,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : True,
    u'16' : True,
    u'17' : True,
    u'18' : True,
    u'19' : True,
    u'20' : True,
    u'21' : True,
    u'22' : True,
    u'23' : True,
    u'24' : True,
    u'25' : True,
    u'26' : True
    
})
# Out:
# update_time {
#   seconds: 1599327372
#   nanos: 502981000
# }

# %%
#insert PCRoom checklist(17lists)

#case1 : random
doc_ref = db.collection(u'checkListPC').document(u'C피시방 신촌점')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : False,
    u'4' : True,
    u'5' : False,
    u'6' : True,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : True,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : True,
    u'15' : False,
    u'16' : False,
    u'17' : False
      
})
# Out:
# update_time {
#   seconds: 1599327485
#   nanos: 106525000
# }

# %%
#insert karaoke checklist(18lists)

#case1 : random
doc_ref = db.collection(u'checkListKaraoke').document(u'D노래방 신촌점')
doc_ref.set({
    u'1' : True,
    u'2' : True,
    u'3' : True,
    u'4' : True,
    u'5' : True,
    u'6' : True,
    u'7' : True,
    u'8' : True,
    u'9' : True,
    u'10' : False,
    u'11' : True,
    u'12' : True,
    u'13' : True,
    u'14' : False,
    u'15' : True,
    u'16' : False,
    u'17' : False,
    u'18' : True
      
})
# Out:
# update_time {
#   seconds: 1599327655
#   nanos: 678956000
# }
